# %%
print('Hello!')
# Out:
# Hello!

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2025-12-17 17:42:28.622896

# %% [markdown]
# ### Heading 3

# %%
d = datetime.date.today()

print(d)

# %%
d.strftime()

# %%
d.isoweekday

# %% [markdown]
# <h1>Heading!!</h1>

# %% [markdown]
# <ul>
#     <li>First</li>
#     <li>Second</li>
# </ul>

# %% [markdown]
# ***

# %% [markdown]
# <div class="alert alert-block alert-danger">Red Box
# </div>

# %%
from IPython.display import Image
Image(url="https://www.srikanthtechnologies.com/banner.jpg")
# Out:
# <img src="https://www.srikanthtechnologies.com/banner.jpg"/>

# %%
# !cd
# Out:
# C:\classroom\dec15

# %%
names = !type names.txt

# %%
names
# Out:
# ['Java', 'Python', 'JavaScript', 'C#', 'C++']

# %%
ext = "*.txt"
# !dir {ext}
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 482A-6FBC
#
#  Directory of C:\classroom\dec15
#
# 17-12-2025  17:25                35 names.txt
#                1 File(s)             35 bytes
#                0 Dir(s)  820,684,840,960 bytes free

# %%
# %pwd
# Out:
# 'C:\\classroom\\dec15'

# %%
# !cd
# Out:
# C:\classroom\dec15

# %%
#%env

# %%
# %%js
# var d = new Date()
# alert(d)

# %%
# %%capture output
for n in range(1,11):
    print(n*n)

# %%
print(output.stdout)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
